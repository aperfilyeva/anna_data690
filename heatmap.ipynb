# %% [markdown]
# <a href="https://colab.research.google.com/github/aperfilyeva/anna_data690/blob/main/heatmap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # UCI - Heart Disease Dataset
#
# - age: age of the person in years.
# - sex: 1 for male 0 for female
# - cp: chest pain (0,1,2,3)
# - trestbps: rest BP
# - chol: cholestoral
# - fbs: blood sugar on fasting.
# - restecg: electrocardiographic
# - thalach: maximum heart rate.
# - exang: exercise with angina
# - oldpeak: heart condition while exercising.
# - slope: slope of the heart while exercising
# - ca: indicate the blood movement
# - thal: thalium stress (the more the danger)
# - num: 1-person tent to have disease, 0-person dosnt tent to have any heart disease.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

#data_url = "https://raw.githubusercontent.com/wcj365/python-stats-dataviz/master/data/heart_disease_uci.csv"
data_url = "https://raw.githubusercontent.com/wcj365/python-stats-dataviz/master/data/cleveland_heart_disease.csv"

# %%
df = pd.read_csv(data_url)

df.shape
# Out:
# (303, 14)

# %%
df.sample(5)
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  halach  exang  oldpeak  \
# 284  61.0  1.0  4.0     148.0  203.0  0.0      0.0   161.0    0.0      0.0
# 257  76.0  0.0  3.0     140.0  197.0  0.0      1.0   116.0    0.0      1.1
# 47   50.0  1.0  4.0     150.0  243.0  0.0      2.0   128.0    0.0      2.6
# 205  45.0  1.0  4.0     142.0  309.0  0.0      2.0   147.0    1.0      0.0
# 129  62.0  0.0  4.0     124.0  209.0  0.0      0.0   163.0    0.0      0.0
#
#      slope   ca thal  num
# 284    1.0  1.0  7.0    2
# 257    2.0  0.0  3.0    0
# 47     2.0  0.0  7.0    4
# 205    2.0  3.0  7.0    3
# 129    1.0  0.0  3.0    0

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(), annot=True, cmap=("RdYlGn"))
plt.show()

# %%
px.imshow(df.corr().round(decimals=2), text_auto=True, height=1000)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
